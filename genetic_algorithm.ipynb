# %%
import random
def fitness(chromosome):
    x = int(''.join(map(str, chromosome)), 2)
    return x ** 2
def generate_chromosome(length):
    return [random.randint(0, 1) for _ in range(length)]

def generate_population(size, chromosome_length):
    return [generate_chromosome(chromosome_length) for _ in range(size)]

population_size = 10
chromosome_length = 5
population = generate_population(population_size, chromosome_length)
fitnesses = [fitness(chromosome) for chromosome in population]
def select_pair(population, fitnesses):
    total_fitness = sum(fitnesses)
    selection_probs = [f / total_fitness for f in fitnesses]
    parent1 = population[random.choices(range(len(population)), selection_probs)[0]]
    parent2 = population[random.choices(range(len(population)), selection_probs)[0]]
    return parent1, parent2
def crossover(parent1, parent2):
    point = random.randint(1, len(parent1) - 1)
    offspring1 = parent1[:point] + parent2[point:]
    offspring2 = parent2[:point] + parent1[point:]
    return offspring1, offspring2
def mutate(chromosome, mutation_rate):
    return [gene if random.random() > mutation_rate else 1 - gene for gene in chromosome]

mutation_rate = 0.01
num_generations = 100

for generation in range(num_generations):
    new_population = []

    for _ in range(population_size // 2):  # Assuming each iteration creates 2 offspring
        parent1, parent2 = select_pair(population, fitnesses)
        offspring1, offspring2 = crossover(parent1, parent2)
        offspring1 = mutate(offspring1, mutation_rate)
        offspring2 = mutate(offspring2, mutation_rate)
        new_population.extend([offspring1, offspring2])

    population = new_population
    best_individual = ''
    best_fitness = 0
    for chromosome in population:
        chromosome_fitness = fitness(chromosome)
        if chromosome_fitness > best_fitness:
            best_fitness = chromosome_fitness
            best_individual = chromosome
    # Optionally, you can print or log the best fitness each generation
    print(f"Generation {generation}: Best Individual = {best_individual}, Fitness = {best_fitness}")
# Out:
# Generation 0: Best Individual = [1, 1, 0, 1, 0], Fitness = 676
# Generation 1: Best Individual = [1, 1, 0, 1, 0], Fitness = 676
# Generation 2: Best Individual = [1, 1, 0, 1, 0], Fitness = 676
# Generation 3: Best Individual = [1, 1, 1, 0, 0], Fitness = 784
# Generation 4: Best Individual = [1, 1, 1, 0, 0], Fitness = 784
# Generation 5: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 6: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 7: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 8: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 9: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 10: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 11: Best Individual = [1, 0, 1, 1, 0], Fitness = 484
# Generation 12: Best Individual = [1, 0, 1, 1, 0], Fitness = 484
# Generation 13: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 14: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 15: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 16: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 17: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 18: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 19: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 20: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 21: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 22: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 23: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 24: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 25: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 26: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 27: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 28: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 29: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 30: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 31: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 32: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 33: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 34: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 35: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 36: Best Individual = [1, 1, 1, 0, 0], Fitness = 784
# Generation 37: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 38: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 39: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 40: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 41: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 42: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 43: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 44: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 45: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 46: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 47: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 48: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 49: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 50: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 51: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 52: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 53: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 54: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 55: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 56: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 57: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 58: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 59: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 60: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 61: Best Individual = [1, 1, 1, 1, 0], Fitness = 900
# Generation 62: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 63: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 64: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 65: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 66: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 67: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 68: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 69: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 70: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 71: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 72: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 73: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 74: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 75: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 76: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 77: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 78: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 79: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 80: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 81: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 82: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 83: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 84: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 85: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 86: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 87: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 88: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 89: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 90: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 91: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 92: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 93: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 94: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 95: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 96: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 97: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 98: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
# Generation 99: Best Individual = [1, 1, 1, 1, 1], Fitness = 961
